# %%
import pandas as pd
from sklearn.preprocessing import minmax_scale

# %%
df = pd.DataFrame({
    'dataset':['Webface', 'Celeba', 'Webface-full', 'Webface-full+Celeba'],
    'train': [52917, 335219, 367311, 1067833],
    'time': [7, 51, 63, 178],
    'convergence': [10, 15, 6, 13],
})

# %%
for a in ['train', 'time', 'convergence']:
    df[a] = df[a] / df[a].max()

# %%
# %matplotlib inline
df.plot.bar(x='dataset')

# %%
df1 = pd.DataFrame({
    'stage':['Start', 'Alignment', 'Augmentation', 'Bigger Datasets', 'More features', 'Merge DeepIDs'],
    'error': [0.248, 0.159, 0.131, 0.0936, 0.0867, 0.0708],
})

# %%
df1.plot.bar(x='stage')
